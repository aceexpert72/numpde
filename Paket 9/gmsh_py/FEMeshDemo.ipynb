# %% [markdown]
# # Demo for GmshMesh

# %%
from FEMesh import readmsh
import numpy as np

# %% [markdown]
# ## Simple mesh

# %%
m = readmsh('gmsh/rectangle-0.msh')
m.plot()

# %%
m = readmsh('gmsh/complex.msh')
m.plot()

# %% [markdown]
# Plot with colors

# %%
m.plot(np.random.rand(m.Nn))
