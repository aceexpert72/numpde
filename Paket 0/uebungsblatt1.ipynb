# %%
# Ubungsblatt 1: Arbeiten mit Python und Jupyter Notebooks

import numpy as np
import matplotlib.pyplot as plt 
import scipy as sp 
from math import *

# Aufgabe 1

n = 10 
A = np.zeros((n, n))

for i in range(n):
   A[i, :] = np.linspace(1+i, n+i, n)

#print(A)

# Aufgabe 2
# 2.1
x = np.linspace(0,2*pi,200)
y_f = np.sin(3*pi*np.sin(x))
y_g = np.cos(np.exp(0.7*x))

plt.plot(x,y_f)
plt.show
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.clf()

plt.plot(x,y_g)
plt.show
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.clf()

# 2.2
t = np.linspace(0,20*pi,1000)
k = 7.23
l = 2.55
y1 = (1-k)*np.cos(t)+l*k*np.cos(((1-k)/k)*t)
y2 = (1-k)*np.sin(t)+l*k*np.sin(((1-k)/k)*t)
plt.plot(y1,y2)
plt.show
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.clf()

# Aufgabe 3
# 3.1
x = np.linspace(-2,3,1000)
def pwfunc(x):
    y = np.empty_like(x) 

    for i in range(len(x)):
        if x[i] <= -1:
            y[i] = 3
        elif x[i] >= 2:
            y[i] = 4 * x[i] - 8
        else:
            y[i] = -x[i] ** 2 + 4

    return y

y = pwfunc(x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show
plt.clf()

# 3.2
x = np.linspace(-2,2,1000)
a_i = np.linspace(-2,2,10)

def fa(a, x):
    return np.exp(a * x)

for a in a_i:
    y = fa(a, x)
    plt.plot(x, y, label=f'a = {a}')

plt.xlabel('x')
plt.ylabel('fa')
#plt.legend()
plt.grid(True)
plt.title('Funktionenschar fa = exp(ax) für verschiedene a')
plt.show()
